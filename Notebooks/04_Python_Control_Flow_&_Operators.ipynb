# %% [markdown]
# ## 1️⃣ Control Flow 🔀
#
# **Control flow** determines the order in which statements are executed. Python uses:
#
# 1. **Sequential** — code runs line by line (default)
# 2. **Selection** — `if`, `elif`, `else` (conditional branching)
# 3. **Iteration** — `for`, `while` (loops)
# 4. **Exception Handling** — `try`, `except` (error handling)
#
# ```
# ┌──────────────┐
# │   Start      │
# └──────┬───────┘
#        ▼
# ┌──────────────┐     Yes    ┌──────────────┐
# │  Condition?  │ ──────────▶│  Do Action A │
# └──────┬───────┘            └──────────────┘
#        │ No
#        ▼
# ┌──────────────┐
# │  Do Action B │
# └──────┬───────┘
#        ▼
# ┌──────────────┐
# │     End      │
# └──────────────┘
# ```
#
# > 💡 We'll cover each control flow structure in detail in the following sections.

# %%
# ============================================================
# Quick overview of control flow structures
# ============================================================

# --- Sequential (default) ---
print("Step 1: Variable assignment")
x = 10
print("Step 2: Calculation")
y = x * 2
print(f"Step 3: Result = {y}")
# Out:
# Step 1: Variable assignment
# Step 2: Calculation
# Step 3: Result = 20

# %%
# --- Selection (if/else) ---
print("\n--- Selection ---")
temperature = 30
if temperature > 25:
    print(f"🌡️ {temperature}°C → It's hot outside!")
else:
    print(f"🌡️ {temperature}°C → Nice weather!")
# Out:
# --- Selection ---
# 🌡️ 30°C → It's hot outside!

# %%
# --- Iteration (for loop) ---
print("\n--- Iteration ---")
for i in range(1, 4):
    print(f"Loop iteration {i}")
# Out:
# --- Iteration ---
# Loop iteration 1
# Loop iteration 2
# Loop iteration 3

# %%
# --- Exception Handling (try/except) ---
print("\n--- Exception Handling ---")
try:
    result = 10 / 0        # This will cause a ZeroDivisionError
except ZeroDivisionError:
    print("⚠️ Cannot divide by zero!")
finally:
    print("✅ This always executes (finally block)")
# Out:
# --- Exception Handling ---
# ⚠️ Cannot divide by zero!
# ✅ This always executes (finally block)

# %% [markdown]
# ---
# ## 2️⃣ Boolean Functions: `bool`, `all`, `any`, `isinstance` ✅❌
#
# ### Truthy vs Falsy Values:
# | Falsy (evaluates to `False`) | Truthy (evaluates to `True`) |
# |---|---|
# | `False`, `0`, `0.0` | `True`, any non-zero number |
# | `""` (empty string) | Any non-empty string |
# | `[]`, `()`, `{}`, `set()` | Any non-empty collection |
# | `None` | Everything else |

# %%
# ============================================================
# bool() — converts any value to True or False
# ============================================================
print("=== bool() function ===")
# Falsy values
print(f"bool(0)      = {bool(0)}")        # False
print(f"bool(0.0)    = {bool(0.0)}")      # False
print(f"bool('')     = {bool('')}")        # False
print(f"bool([])     = {bool([])}")        # False
print(f"bool(None)   = {bool(None)}")     # False

# Truthy values
print(f"bool(1)      = {bool(1)}")        # True
print(f"bool(-5)     = {bool(-5)}")       # True (any non-zero)
print(f"bool('Hi')   = {bool('Hi')}")     # True
print(f"bool([1,2])  = {bool([1, 2])}")   # True
# Out:
# === bool() function ===
# bool(0)      = False
# bool(0.0)    = False
# bool('')     = False
# bool([])     = False
# bool(None)   = False
# bool(1)      = True
# bool(-5)     = True
# bool('Hi')   = True
# bool([1,2])  = True

# %%
# ============================================================
# all() — returns True if ALL elements are truthy
# ============================================================
print("\n=== all() function ===")
print(f"all([True, True, True])   = {all([True, True, True])}")    # True
print(f"all([True, False, True])  = {all([True, False, True])}")   # False
print(f"all([1, 2, 3])            = {all([1, 2, 3])}")             # True
print(f"all([1, 0, 3])            = {all([1, 0, 3])}")             # False (0 is falsy)
print(f"all([])                   = {all([])}")                     # True (vacuously true!)

# Practical example: Check if all students passed
grades = [75, 80, 92, 68, 85]
all_passed = all(g >= 60 for g in grades)
print(f"\nAll students passed (≥60)? {all_passed}")
# Out:
# === all() function ===
# all([True, True, True])   = True
# all([True, False, True])  = False
# all([1, 2, 3])            = True
# all([1, 0, 3])            = False
# all([])                   = True
#
# All students passed (≥60)? True

# %%
# ============================================================
# any() — returns True if ANY element is truthy
# ============================================================
print("\n=== any() function ===")
print(f"any([False, False, True]) = {any([False, False, True])}")  # True
print(f"any([False, False, False])= {any([False, False, False])}")  # False
print(f"any([0, 0, 1])           = {any([0, 0, 1])}")              # True
print(f"any([])                  = {any([])}")                      # False

# Practical example: Check if any student got an A
grades = [75, 80, 92, 68, 85]
has_a_student = any(g >= 90 for g in grades)
print(f"\nAny student got an A (≥90)? {has_a_student}")
# Out:
# === any() function ===
# any([False, False, True]) = True
# any([False, False, False])= False
# any([0, 0, 1])           = True
# any([])                  = False
#
# Any student got an A (≥90)? True

# %%
# ============================================================
# isinstance() — check if object is of a specific type
# ============================================================
print("\n=== isinstance() function ===")
x = 42
print(f"isinstance(42, int)       = {isinstance(x, int)}")         # True
print(f"isinstance(42, float)     = {isinstance(x, float)}")       # False
print(f"isinstance(42, (int,float)) = {isinstance(x, (int, float))}")  # True (check multiple)
print(f"isinstance('hi', str)     = {isinstance('hi', str)}")      # True
print(f"isinstance([1,2], list)   = {isinstance([1,2], list)}")    # True
print(f"isinstance(True, int)     = {isinstance(True, int)}")      # True! (bool is subclass of int)
# Out:
# === isinstance() function ===
# isinstance(42, int)       = True
# isinstance(42, float)     = False
# isinstance(42, (int,float)) = True
# isinstance('hi', str)     = True
# isinstance([1,2], list)   = True
# isinstance(True, int)     = True

# %% [markdown]
# ---
# ## 3️⃣ Comparison Operators ⚖️
#
# Comparison operators compare two values and return a **boolean** (`True` or `False`).
#
# | Operator | Description | Example | Result |
# |---|---|---|---|
# | `==` | Equal to | `5 == 5` | `True` |
# | `!=` | Not equal to | `5 != 3` | `True` |
# | `>` | Greater than | `5 > 3` | `True` |
# | `<` | Less than | `5 < 3` | `False` |
# | `>=` | Greater than or equal | `5 >= 5` | `True` |
# | `<=` | Less than or equal | `3 <= 5` | `True` |
#
# > 💡 **Chained comparisons:** Python allows `1 < x < 10` (equivalent to `1 < x and x < 10`)

# %%
# ============================================================
# Comparison Operators
# ============================================================
a, b = 10, 20
print(f"a = {a}, b = {b}")
print(f"a == b  → {a == b}")    # Equal to
print(f"a != b  → {a != b}")    # Not equal to
print(f"a > b   → {a > b}")     # Greater than
print(f"a < b   → {a < b}")     # Less than
print(f"a >= b  → {a >= b}")    # Greater than or equal
print(f"a <= b  → {a <= b}")    # Less than or equal
# Out:
# a = 10, b = 20
# a == b  → False
# a != b  → True
# a > b   → False
# a < b   → True
# a >= b  → False
# a <= b  → True

# %%
# ============================================================
# Chained comparisons — Pythonic way!
# ============================================================
print("\n--- Chained Comparisons ---")
x = 15
print(f"x = {x}")
print(f"10 < x < 20  → {10 < x < 20}")    # True: x is between 10 and 20
print(f"1 < x < 10   → {1 < x < 10}")     # False: x is not between 1 and 10
print(f"10 <= x <= 20 → {10 <= x <= 20}")  # True: inclusive range
# Out:
# --- Chained Comparisons ---
# x = 15
# 10 < x < 20  → True
# 1 < x < 10   → False
# 10 <= x <= 20 → True

# %%
# ============================================================
# Comparing strings (lexicographic order)
# ============================================================
print("\n--- String Comparison ---")
print(f"'apple' < 'banana'  → {'apple' < 'banana'}")    # True (a < b)
print(f"'abc' == 'abc'      → {'abc' == 'abc'}")        # True
print(f"'ABC' < 'abc'       → {'ABC' < 'abc'}")        # True (uppercase < lowercase)
# Out:
# --- String Comparison ---
# 'apple' < 'banana'  → True
# 'abc' == 'abc'      → True
# 'ABC' < 'abc'       → True

# %% [markdown]
# ---
# ## 4️⃣ Logical Operators 🔗
#
# Logical operators combine boolean expressions.
#
# | Operator | Description | Example | Result |
# |---|---|---|---|
# | `and` | True if **both** are True | `True and False` | `False` |
# | `or` | True if **at least one** is True | `True or False` | `True` |
# | `not` | Inverts the boolean | `not True` | `False` |
#
# ### 📊 Truth Table:
# | A | B | A and B | A or B | not A |
# |---|---|---|---|---|
# | True | True | True | True | False |
# | True | False | False | True | False |
# | False | True | False | True | True |
# | False | False | False | False | True |
#
# > 💡 **Short-circuit evaluation:** Python stops evaluating as soon as the result is determined.

# %%
# ============================================================
# Logical Operators: and, or, not
# ============================================================
x, y = True, False
print(f"x = {x}, y = {y}")
print(f"x and y → {x and y}")   # False (both must be True)
print(f"x or y  → {x or y}")    # True  (at least one True)
print(f"not x   → {not x}")     # False (inverts True)
print(f"not y   → {not y}")     # True  (inverts False)
# Out:
# x = True, y = False
# x and y → False
# x or y  → True
# not x   → False
# not y   → True

# %%
# ============================================================
# Practical examples
# ============================================================
age = 25
income = 50000

# Check if eligible for loan (age 18-65 AND income > 30000)
eligible = (18 <= age <= 65) and (income > 30000)
print(f"\nAge: {age}, Income: {income}")
print(f"Loan eligible? {eligible}")

# Check if weekend or holiday
is_weekend = True
is_holiday = False
day_off = is_weekend or is_holiday
print(f"\nWeekend: {is_weekend}, Holiday: {is_holiday}")
print(f"Day off? {day_off}")
# Out:
# Age: 25, Income: 50000
# Loan eligible? True
#
# Weekend: True, Holiday: False
# Day off? True

# %%
# ============================================================
# Short-circuit evaluation
# ============================================================
print("\n--- Short-circuit Evaluation ---")
# 'and' stops at first False
print(f"False and print('Hi') → evaluates to: {False and 'never reached'}")
# 'or' stops at first True
print(f"True or print('Hi')  → evaluates to: {True or 'never reached'}")

# Practical use: safe division
denominator = 0
result = denominator != 0 and (100 / denominator)
print(f"Safe division result: {result}")  # False (short-circuited, no ZeroDivisionError!)
# Out:
# --- Short-circuit Evaluation ---
# False and print('Hi') → evaluates to: False
# True or print('Hi')  → evaluates to: True
# Safe division result: False

# %% [markdown]
# ---
# ## 5️⃣ Membership & Identity Operators 🔍
#
# ### 🏠 Membership Operators (`in`, `not in`):
# Check if a value **exists in** a sequence (string, list, tuple, set, dict).
#
# | Operator | Description | Example |
# |---|---|---|
# | `in` | True if value is found | `'a' in 'abc'` → `True` |
# | `not in` | True if value is NOT found | `'z' not in 'abc'` → `True` |
#
# ### 🆔 Identity Operators (`is`, `is not`):
# Check if two variables **point to the same object in memory** (not just equal values).
#
# | Operator | Description | Example |
# |---|---|---|
# | `is` | True if same object | `a is b` |
# | `is not` | True if different objects | `a is not b` |
#
# > ⚠️ **`==` checks value equality, `is` checks identity (same memory location)**

# %%
# ============================================================
# Membership Operators: in, not in
# ============================================================
print("=== Membership Operators ===")

# In strings
text = "Hello, Python!"
print(f"'Python' in text     → {'Python' in text}")       # True
print(f"'Java' in text       → {'Java' in text}")         # False
print(f"'Java' not in text   → {'Java' not in text}")     # True
# Out:
# === Membership Operators ===
# 'Python' in text     → True
# 'Java' in text       → False
# 'Java' not in text   → True

# %%
# In lists
fruits = ["apple", "banana", "cherry"]
print(f"\n'banana' in fruits  → {'banana' in fruits}")    # True
print(f"'grape' in fruits    → {'grape' in fruits}")       # False
# Out:
# 'banana' in fruits  → True
# 'grape' in fruits    → False

# %%
# In dictionaries (checks KEYS, not values!)
student = {"name": "Ali", "age": 20}
print(f"\n'name' in student   → {'name' in student}")     # True
print(f"'Ali' in student     → {'Ali' in student}")        # False (checks keys!)
print(f"'Ali' in student.values() → {'Ali' in student.values()}")  # True
# Out:
# 'name' in student   → True
# 'Ali' in student     → False
# 'Ali' in student.values() → True

# %%
# ============================================================
# Identity Operators: is, is not
# ============================================================
print("\n=== Identity Operators ===")

# Small integers are cached in Python (-5 to 256)
a = 256
b = 256
print(f"a = {a}, b = {b}")
print(f"a == b  → {a == b}")    # True (same value)
print(f"a is b  → {a is b}")    # True (same object — cached!)
# Out:
# === Identity Operators ===
# a = 256, b = 256
# a == b  → True
# a is b  → True

# %%
# Larger integers may NOT be cached
x = [1, 2, 3]
y = [1, 2, 3]
print(f"\nx = {x}, y = {y}")
print(f"x == y  → {x == y}")    # True (same values)
print(f"x is y  → {x is y}")    # False (different objects in memory!)

z = x                            # z points to same object as x
print(f"\nz = x")
print(f"x is z  → {x is z}")    # True (same object!)
# Out:
# x = [1, 2, 3], y = [1, 2, 3]
# x == y  → True
# x is y  → False
#
# z = x
# x is z  → True

# %%
# Common use: checking for None
value = None
print(f"\nvalue is None → {value is None}")   # ✅ Preferred way
print(f"value == None → {value == None}")       # Works but not recommended
# Out:
# value is None → True
# value == None → True

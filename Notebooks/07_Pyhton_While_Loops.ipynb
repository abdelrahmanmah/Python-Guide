# %% [markdown]
# ## 1️⃣ While Loops 🔄
#
# The `while` loop repeats **as long as the condition is True**.
#
# ### Syntax:
# ```python
# while condition:
#     # code block
#     # update condition to avoid infinite loop!
# ```
#
# > ⚠️ **Always ensure the condition eventually becomes False**, or use `break` to exit!

# %%
# ============================================================
# Basic while loop — countdown
# ============================================================
print("=== Countdown ===")
count = 5
while count > 0:
    print(f"{'🟢' * count} {count}")
    count -= 1
print("🚀 Liftoff!")
# Out:
# === Countdown ===
# 🟢🟢🟢🟢🟢 5
# 🟢🟢🟢🟢 4
# 🟢🟢🟢 3
# 🟢🟢 2
# 🟢 1
# 🚀 Liftoff!

# %%
# ============================================================
# While with user-like input simulation
# ============================================================
print("\n=== Sum Calculator ===")
numbers = [10, 20, 30, 0]  # Simulating input (0 = stop)
total = 0
i = 0
while numbers[i] != 0:
    total += numbers[i]
    print(f"  Added {numbers[i]}, running total = {total}")
    i += 1
print(f"Final total: {total}")
# Out:
# === Sum Calculator ===
#   Added 10, running total = 10
#   Added 20, running total = 30
#   Added 30, running total = 60
# Final total: 60

# %%
# ============================================================
# While-else (similar to for-else)
# ============================================================
print("\n=== While-Else ===")
n = 10
while n > 0:
    if n == 5:
        print(f"Found {n}!")
        # break  # Uncomment to skip the else block
    n -= 1
else:
    print("Loop completed without break!")
# Out:
# === While-Else ===
# Found 5!
# Loop completed without break!

# %%
# ============================================================
# Practical: Guessing game simulation
# ============================================================
print("\n=== Guessing Game (Simulated) ===")
import random
secret = 7
guesses = [3, 9, 5, 7]  # Simulated guesses
attempt = 0

while attempt < len(guesses):
    guess = guesses[attempt]
    attempt += 1
    if guess == secret:
        print(f"🎉 Correct! The number was {secret}! (Attempt #{attempt})")
        break
    elif guess < secret:
        print(f"  Guess {guess}: Too low! ⬆️")
    else:
        print(f"  Guess {guess}: Too high! ⬇️")
# Out:
# === Guessing Game (Simulated) ===
#   Guess 3: Too low! ⬆️
#   Guess 9: Too high! ⬇️
#   Guess 5: Too low! ⬆️
# 🎉 Correct! The number was 7! (Attempt #4)

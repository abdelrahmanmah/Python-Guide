# %% [markdown]
# ## 1️⃣ Comments 💬
#
# Comments are **non-executable text** in your code used to:
# - 📝 Explain what the code does
# - 🐛 Temporarily disable code for debugging
# - 📖 Improve code readability for others (and future you!)
#
# ### Types of Comments:
# 1. **Single-line comment:** starts with `#`
# 2. **Multi-line comment:** use multiple `#` or triple quotes `\"\"\"` (technically a docstring)
# 3. **Inline comment:** `#` at the end of a line of code

# %%
# ============================================================
# Single-line comment — starts with '#'
# ============================================================
# This is a single-line comment
name = "Python"  # This is an inline comment

# ============================================================
# Multi-line comments — use multiple '#' lines
# ============================================================
# This is line 1 of a multi-line comment
# This is line 2 of a multi-line comment
# This is line 3 of a multi-line comment

# ============================================================
# Docstrings — triple quotes (used for documentation)
# ============================================================
"""
This is a docstring.
It can span multiple lines.
Often used to document functions, classes, and modules.
"""
# Out:
# '\nThis is a docstring.\nIt can span multiple lines.\nOften used to document functions, classes, and modules.\n'

# %% [markdown]
# ---
# ## 2️⃣ Print Function 🖨️
#
# The `print()` function outputs text or values to the console. It's the most commonly used function in Python.
#
# ### Syntax:
# ```python
# print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False)
# ```
#
# | Parameter | Description | Default |
# |---|---|---|
# | `*objects` | Values to print (any number) | — |
# | `sep` | Separator between multiple values | `' '` (space) |
# | `end` | What to print at the end | `'\n'` (newline) |
# | `file` | Output destination | `sys.stdout` |
# | `flush` | Force flush the stream | `False` |

# %%
# ============================================================
# Basic print
# ============================================================
print("Hello, World!")           # Simple string
print(42)                        # Integer
print(3.14)                      # Float
print(True)                      # Boolean
# Out:
# Hello, World!
# 42
# 3.14
# True

# %%
# ============================================================
# Printing multiple values
# ============================================================
print("Name:", "Ali", "Age:", 25)  # Multiple values separated by space
# Out:
# Name: Ali Age: 25

# %%
# ============================================================
# Using 'sep' parameter — custom separator
# ============================================================
print("2026", "02", "21", sep="-")      # Output: 2026-02-21
print("apple", "banana", "cherry", sep=" | ")  # Output: apple | banana | cherry
# Out:
# 2026-02-21
# apple | banana | cherry

# %%
# ============================================================
# Using 'end' parameter — change line ending
# ============================================================
print("Hello", end=" ")     # No newline at end
print("World!")              # Continues on same line → "Hello World!"
# Out:
# Hello World!

# %%
# ============================================================
# String formatting methods
# ============================================================
name = "Ganna"
age = 22

# Method 1: f-strings (recommended — Python 3.6+)
print(f"My name is {name} and I am {age} years old.")

# Method 2: .format() method
print("My name is {} and I am {} years old.".format(name, age))

# Method 3: % formatting (old style)
print("My name is %s and I am %d years old." % (name, age))

# Method 4: String concatenation
print("My name is " + name + " and I am " + str(age) + " years old.")
# Out:
# My name is Ganna and I am 22 years old.
# My name is Ganna and I am 22 years old.
# My name is Ganna and I am 22 years old.
# My name is Ganna and I am 22 years old.

# %%
# ==============================
# Escape Sequences in Python
# ==============================

# \n - Newline
print("First Line\nSecond Line")

# \t - Tab
print("Name:\tAhmed")
print("Age:\t25")

# \\ - Literal Backslash
print("Path: C:\\Users\\Ahmed\\Desktop")

# \' and \" - Quotes inside a string
print('He said: \'Hello there!\'')
print("She said: \"Welcome!\"")
# Out:
# First Line
# Second Line
# Name:	Ahmed
# Age:	25
# Path: C:\Users\Ahmed\Desktop
# He said: 'Hello there!'
# She said: "Welcome!"

# %% [markdown]
# ---
# ## 3️⃣ Variables 📦
#
# A **variable** is a named container that stores a value in memory. In Python, you don't need to declare the type — it's **dynamically typed**.
#
# ### 📏 Variable Naming Rules:
# | Rule | Valid ✅ | Invalid ❌ |
# |---|---|---|
# | Must start with a letter or `_` | `name`, `_age` | `1name`, `@age` |
# | Can contain letters, digits, `_` | `my_var2` | `my-var`, `my var` |
# | Case-sensitive | `Name ≠ name` | — |
# | Cannot be a reserved keyword | `score` | `class`, `for`, `if` |
#
# ### 🏷️ Naming Conventions:
# - **snake_case** → variables & functions: `my_variable`
# - **PascalCase** → classes: `MyClass`
# - **UPPER_CASE** → constants: `MAX_SIZE`

# %%
# ============================================================
# Creating variables — no type declaration needed!
# ============================================================
name = "Python"          # str (string)
age = 32                 # int (integer)
pi = 3.14159             # float
is_awesome = True        # bool (boolean)

print(f"Language: {name}, Age: {age}, Pi: {pi}, Awesome: {is_awesome}")
# Out:
# Language: Python, Age: 32, Pi: 3.14159, Awesome: True

# %%
# ============================================================
# Multiple assignment — assign several variables at once
# ============================================================
x, y, z = 1, 2, 3       # Each gets a different value
print(f"x={x}, y={y}, z={z}")

a = b = c = 100          # All get the same value
print(f"a={a}, b={b}, c={c}")
# Out:
# x=1, y=2, z=3
# a=100, b=100, c=100

# %%
# ============================================================
# Swapping variables — Pythonic way (no temp variable needed!)
# ============================================================
x, y = 10, 20
print(f"Before swap: x={x}, y={y}")
x, y = y, x              # Swap in one line!
print(f"After swap:  x={x}, y={y}")
# Out:
# Before swap: x=10, y=20
# After swap:  x=20, y=10

# %%
# ============================================================
# Checking variable type with type()
# ============================================================
print(f"\nType of name: {type(name)}")
print(f"Type of age:  {type(age)}")
print(f"Type of pi:   {type(pi)}")
print(f"Type of is_awesome: {type(is_awesome)}")
# Out:
# Type of name: <class 'str'>
# Type of age:  <class 'int'>
# Type of pi:   <class 'float'>
# Type of is_awesome: <class 'bool'>

# %%
# ============================================================
# Deleting a variable with del
# ============================================================
temp = "I will be deleted"
print(f"\ntemp = '{temp}'")
del temp
# print(temp)  # ❌ This would raise NameError: name 'temp' is not defined
print("Variable 'temp' has been deleted!")
# Out:
# temp = 'I will be deleted'
# Variable 'temp' has been deleted!

# %% [markdown]
# ---
# ## 4️⃣ Input Function ⌨️
#
# The `input()` function reads user input from the keyboard. It **always returns a string**, so you need to convert (cast) it for numerical operations.
#
# ### Syntax:
# ```python
# variable = input("prompt message")
# ```
#
# > ⚠️ **Important:** `input()` always returns a `str`. Use `int()`, `float()`, etc. to convert.

# %%
# ============================================================
# Basic input — always returns a string
# ============================================================
name = input("Enter your name: ")   # Uncomment to test interactively
print(f"Hello, {name}!")
# Out:
# Hello, Abdelrahman!

# %%
# ============================================================
# Type conversion (casting) for numerical input
# ============================================================
age = int(input("Enter your age: "))        # Convert to integer
height = float(input("Enter your height: ")) # Convert to float
print(f"Age: {age} (type: {type(age)})")
print(f"Height: {height} (type: {type(height)})")
# Out:
# Age: 20 (type: <class 'int'>)
# Height: 1.79 (type: <class 'float'>)

# %%
# ============================================================
# Example with default values (for non-interactive demo)
# ============================================================
name = "Student"
age = 20
height = 1.75

print(f"👤 Name: {name}")
print(f"🎂 Age: {age} (type: {type(age).__name__})")
print(f"📏 Height: {height}m (type: {type(height).__name__})")
# Out:
# 👤 Name: Student
# 🎂 Age: 20 (type: int)
# 📏 Height: 1.75m (type: float)

# %%
# ============================================================
# Multiple inputs in one line
# ============================================================
x, y = input("Enter two numbers separated by space: ").split()
x, y = int(x), int(y)
print(f"\nSum of {x} and {y} = {x + y}")
# Out:
# Sum of 50 and 70 = 120

# %% [markdown]
# ---
# ## 5️⃣ Data Types 📊
#
# Python has several built-in data types, grouped into categories:
#
# ### 📋 Data Type Categories:
# | Category | Types | Examples |
# |---|---|---|
# | **Text** | `str` | `"Hello"`, `'World'` |
# | **Numeric** | `int`, `float`, `complex` | `10`, `3.14`, `2+3j` |
# | **Boolean** | `bool` | `True`, `False` |
# | **Sequence** | `list`, `tuple`, `range` | `[1,2]`, `(1,2)`, `range(5)` |
# | **Set** | `set`, `frozenset` | `{1,2,3}` |
# | **Mapping** | `dict` | `{"key": "value"}` |
# | **None** | `NoneType` | `None` |
# | **Binary** | `bytes`, `bytearray`, `memoryview` | `b"hello"` |

# %%
# ============================================================
# Demonstrating all major data types
# ============================================================

# --- Text Type ---
text = "Hello, Python!"
type(text)
# Out:
# str

# %%
# --- Numeric Types ---
integer = 42
floating = 3.14159
complex_num = 2 + 3j

print(type(integer))
print(type(floating))
print(type(complex_num))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
# --- Boolean Type ---
flag = True
print(type(flag))
# Out:
# <class 'bool'>

# %%
# --- Sequence Types ---
my_list = [1, 2, 3, 4, 5]
my_tuple = (10, 20, 30)
my_range = range(0, 10, 2)
print(type(my_list))
print(type(my_tuple))
print(type(my_range))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'range'>

# %%
# --- Set Types ---
my_set = {1, 2, 3, 4, 5}
print(type(my_set))
# Out:
# <class 'set'>

# %%
# --- Mapping Type ---
my_dict = {"name": "Ali", "age": 25}
print(type(my_dict))
# Out:
# <class 'dict'>

# %%
# --- None Type ---
nothing = None
print(type(nothing))
# Out:
# <class 'NoneType'>

# %%
# ============================================================
# Type Conversion (Casting)
# ============================================================
print("\n--- Type Conversion ---")
print(f"int('42')     = {int('42')}")       # str → int
print(f"float('3.14') = {float('3.14')}")   # str → float
print(f"str(100)      = {str(100)!r}")      # int → str
print(f"bool(1)       = {bool(1)}")         # int → bool
print(f"bool(0)       = {bool(0)}")         # 0 is False
print(f"list('abc')   = {list('abc')}")     # str → list
# Out:
# --- Type Conversion ---
# int('42')     = 42
# float('3.14') = 3.14
# str(100)      = '100'
# bool(1)       = True
# bool(0)       = False
# list('abc')   = ['a', 'b', 'c']
